# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料
#     選擇資料:Confused student EEG brainwave data
#     https://www.kaggle.com/wanghaohan/confused-eeg
#     測量學員的腦波，以判斷教學影片的內容是否清晰明確。
#
# 1. 你選的這組資料為何重要
#     能藉以判斷教學影片的品質，並統整出好的影片具備何種特性。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     測量10個學生觀看影片(剪輯片段)時的腦波變化，輔以學員自身的主觀認知。
#
# 3. 蒐集而來的資料型態為何
#     數值，每次腦波分析出的各波段的強度。
#
# 4. 這組資料想解決的問題如何評估
#     觀察具有相同特性的影片的教學狀況。

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#     記錄每日各載客起訖、時間，各車輛閒置時間，以及每日上工與返家的地點。
#     時間以平日/假日區分，地點以地區特性做區分，並對可預測的特殊活動(如演唱會...等)做特殊處理。
#     第一階段可先將閒置時間多的地區的車輛分散到閒置時間少的地區
#     第二階段可針對特殊活動做分析，預測何時/何處會有載客峰值
#     第三階段可從載客路線分析車輛流動預測，以找出車輛整天的最佳載客計畫。
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     將車輛閒置時間控制在合理範圍內
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     車輛相關: 司機的載客紀錄。
#     活動相關: 觀察各特定場所的佈告。
#     地區相關: 政府的"全國土地使用分區查詢系統"。
#
# 3. 蒐集而來的資料型態為何
#     車輛相關: 地點(座標)和時間。
#     活動相關: 時間與分類flag。
#     地區相關: 地點(座標)與分類flag，異動頻率小。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     藉由持續觀測車輛相關紀錄，判斷載客/閒置比率與分佈是否朝向理想值收斂。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_squared_error(y ,y_hat):
    
    idx = 0
    result = 0
    
    for item in y:
        if (not y_hat[idx]) :
            break
            
        result += (item - y_hat[idx])**2
        idx += 1
        
    return result/idx

def mean_absolute_error(y ,y_hat):
    
    idx = 0
    result = 0
    
    for item in y:
        if (not y_hat[idx]) :
            break
            
        result += abs(item - y_hat[idx])
        idx += 1
        
    return result/idx

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 213.663
# The Mean absolute error is 11.706
